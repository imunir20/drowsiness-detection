# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
raw_dir = r'C:\Users\imuni\OneDrive\Desktop\GMU\Classes\CS\CS499\499FinalProject\mrlEyes_2018_01'
for dirpath, dirname, filenames in os.walk(raw_dir):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4] == '0':
            shutil.copy(src = dirpath + '/' + i, dst=r'C:\Users\imuni\OneDrive\Desktop\GMU\Classes\CS\CS499\499FinalProject\preppedData\closedEyes')
        elif i.split('_')[4] == '1':
            shutil.copy(src = dirpath + '/' + i, dst=r'C:\Users\imuni\OneDrive\Desktop\GMU\Classes\CS\CS499\499FinalProject\preppedData\openEyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10257/10257 [01:22<00:00, 123.98it/s]
